# %%
# !pip install pyspark

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime as dt

# %%
from pyspark.sql import SparkSession

# initialise sparkContext
spark = SparkSession.builder \
    .master('local') \
    .appName('myAppName') \
    .config('spark.executor.memory', '5gb') \
    .config("spark.cores.max", "6") \
    .getOrCreate()

sc = spark.sparkContext

# using SQLContext to read parquet file
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

# to read parquet file
id_map = sqlContext.read.parquet('epamdscourseclassification3/id_map.parquet')

# %%
df = pd.read_csv("epamdscourseclassification3/train.csv", parse_dates=[f'time{i+1}' for i in range(10)]

# %%
df
# Out:
#         session_id  webpage1               time1  webpage2  \
# 0                0      9486 2019-02-20 05:57:45       NaN
# 1                1     11722 2019-02-22 07:14:50   12385.0
# 2                2    192149 2018-12-16 12:35:17     659.0
# 3                3     10591 2019-02-13 12:40:35     451.0
# 4                4       438 2018-04-12 06:22:26     425.0
# ...            ...       ...                 ...       ...
# 159964      159964    117685 2018-04-12 09:06:57    3935.0
# 159965      159965     45314 2018-11-25 06:21:54   45314.0
# 159966      159966    165603 2018-03-12 11:56:15  165603.0
# 159967      159967     34745 2018-09-12 10:00:03  195204.0
# 159968      159968     10708 2018-12-19 11:15:22    8940.0
#
#                      time2  webpage3               time3  webpage4  \
# 0                      NaT       NaN                 NaT       NaN
# 1      2019-02-22 07:14:50   50163.0 2019-02-22 07:14:51   12385.0
# 2      2018-12-16 12:35:18  192136.0 2018-12-16 12:35:19  192149.0
# 3      2019-02-13 12:40:35   77580.0 2019-02-13 12:40:35  227821.0
# 4      2018-04-12 06:22:26     529.0 2018-04-12 06:22:28   65685.0
# ...                    ...       ...                 ...       ...
# 159964 2018-04-12 09:07:01     451.0 2018-04-12 09:07:03     828.0
# 159965 2018-11-25 06:21:58    1985.0 2018-11-25 06:22:03   31716.0
# 159966 2018-03-12 11:56:16   28947.0 2018-03-12 11:56:16     646.0
# 159967 2018-09-12 10:00:10   72458.0 2018-09-12 10:00:10   72458.0
# 159968 2018-12-19 11:15:22   10734.0 2018-12-19 11:15:22     438.0
#
#                      time4  webpage5  ...               time6  webpage7  \
# 0                      NaT       NaN  ...                 NaT       NaN
# 1      2019-02-22 07:14:51   12398.0  ... 2019-02-22 07:14:51   50163.0
# 2      2018-12-16 12:35:19     633.0  ... 2018-12-16 12:35:19  192136.0
# 3      2019-02-13 12:40:35     633.0  ... 2019-02-13 12:42:14   10591.0
# 4      2018-04-12 06:22:29  187638.0  ... 2018-04-12 06:22:29     425.0
# ...                    ...       ...  ...                 ...       ...
# 159964 2018-04-12 09:07:03     451.0  ... 2018-04-12 09:07:06   30975.0
# 159965 2018-11-25 06:22:04    1530.0  ... 2018-11-25 06:22:16   31716.0
# 159966 2018-03-12 11:56:17   28947.0  ... 2018-03-12 11:56:17  330924.0
# 159967 2018-09-12 10:01:29   72458.0  ...                 NaT       NaN
# 159968 2018-12-19 11:15:22     659.0  ... 2018-12-19 11:15:23   10734.0
#
#                      time7  webpage8               time8  webpage9  \
# 0                      NaT       NaN                 NaT       NaN
# 1      2019-02-22 07:14:52   50150.0 2019-02-22 07:14:52   19860.0
# 2      2018-12-16 12:35:20  192136.0 2018-12-16 12:35:21  192136.0
# 3      2019-02-13 12:42:14  227834.0 2019-02-13 12:42:15  227834.0
# 4      2018-04-12 06:22:29   65685.0 2018-04-12 06:22:31  187625.0
# ...                    ...       ...                 ...       ...
# 159964 2018-04-12 09:07:07   30975.0 2018-04-12 09:07:09     828.0
# 159965 2018-11-25 06:22:28   31716.0 2018-11-25 06:22:40   31716.0
# 159966 2018-03-12 11:56:18   28947.0 2018-03-12 11:56:18     451.0
# 159967                 NaT       NaN                 NaT       NaN
# 159968 2018-12-19 11:15:23    7562.0 2018-12-19 11:15:23     438.0
#
#                      time9  webpage10              time10  target
# 0                      NaT        NaN                 NaT       0
# 1      2019-02-22 07:15:15    19886.0 2019-02-22 07:15:16       0
# 2      2018-12-16 12:35:22   192136.0 2018-12-16 12:35:24       0
# 3      2019-02-13 12:42:16   227834.0 2019-02-13 12:42:17       0
# 4      2018-04-12 06:22:31   187625.0 2018-04-12 06:22:32       0
# ...                    ...        ...                 ...     ...
# 159964 2018-04-12 09:07:12      828.0 2018-04-12 09:07:13       0
# 159965 2018-11-25 06:22:52     2076.0 2018-11-25 06:22:53       0
# 159966 2018-03-12 11:56:18      425.0 2018-03-12 11:56:18       0
# 159967                 NaT        NaN                 NaT       0
# 159968 2018-12-19 11:15:24     7562.0 2018-12-19 11:15:24       0
#
# [159969 rows x 22 columns]

# %% [markdown]
# ## Data preprocessing
#
# First of all we should make some really needable things like deleting useless data (Nans), convert data to another format and so on.

# %%
df.isna().sum() / df.shape[0] * 100
# Out:
# session_id    0.000000
# webpage1      0.000000
# time1         0.000000
# webpage2      1.237115
# time2         1.237115
# webpage3      2.439848
# time3         2.439848
# webpage4      3.480049
# time4         3.480049
# webpage5      4.455863
# time5         4.455863
# webpage6      5.404172
# time6         5.404172
# webpage7      6.286843
# time7         6.286843
# webpage8      7.123255
# time8         7.123255
# webpage9      8.007176
# time9         8.007176
# webpage10     8.822334
# time10        8.822334
# target        0.000000
# dtype: float64

# %%
df.describe()
# Out:
#           session_id       webpage1       webpage2       webpage3  \
# count  159969.000000  159969.000000  157990.000000  156066.000000
# mean    79984.000000   44362.540573   44593.501722   45025.879231
# std     46179.216943   97167.414738   97682.859444   97995.435761
# min         0.000000     165.000000     165.000000     165.000000
# 25%     39992.000000     828.000000     828.000000     828.000000
# 50%     79984.000000    8160.000000    8160.000000    8173.000000
# 75%    119976.000000   30845.000000   30663.000000   31508.000000
# max    159968.000000  540965.000000  540952.000000  540939.000000
#
#             webpage4       webpage5       webpage6       webpage7  \
# count  154402.000000  152841.000000  151324.000000  149912.000000
# mean    45448.173081   45663.769584   45820.414706   46410.833809
# std     98488.571326   98504.193709   98600.684290   99314.768320
# min       165.000000     165.000000     165.000000     165.000000
# 25%       828.000000     828.000000     828.000000     828.000000
# 50%      8238.000000    8693.000000    8810.000000    8940.000000
# 75%     31716.000000   31716.000000   31963.000000   32704.000000
# max    540939.000000  540939.000000  540952.000000  540952.000000
#
#             webpage8       webpage9      webpage10         target
# count  148574.000000  147160.000000  145856.000000  159969.000000
# mean    46813.332925   46971.420053   47558.884736       0.009846
# std     99651.347793   99794.332873  100488.244994       0.098736
# min       165.000000     165.000000     165.000000       0.000000
# 25%       828.000000     828.000000     828.000000       0.000000
# 50%      8953.000000    8953.000000    8953.000000       0.000000
# 75%     33809.000000   33835.000000   34108.000000       0.000000
# max    540965.000000  540965.000000  540965.000000       1.000000

# %%
df.drop(columns="session_id", inplace=True)

# %%
df[df.isna().any(axis=1)]
# Out:
#         webpage1               time1  webpage2               time2  webpage3  \
# 0           9486 2019-02-20 05:57:45       NaN                 NaT       NaN
# 14           425 2019-02-04 05:54:41     425.0 2019-02-04 05:54:55     438.0
# 15         10708 2018-12-12 16:46:18       NaN                 NaT       NaN
# 32           295 2018-12-12 17:52:03     230.0 2018-12-12 17:52:04       NaN
# 34           438 2018-03-12 07:20:53    1621.0 2018-03-12 07:21:46     659.0
# ...          ...                 ...       ...                 ...       ...
# 159930     15414 2019-02-21 07:39:38       NaN                 NaT       NaN
# 159943       425 2018-10-12 06:09:48     425.0 2018-10-12 06:09:50     438.0
# 159946     12645 2018-04-12 08:11:49       NaN                 NaT       NaN
# 159953      4130 2019-02-04 09:54:54     880.0 2019-02-04 09:58:58     867.0
# 159967     34745 2018-09-12 10:00:03  195204.0 2018-09-12 10:00:10   72458.0
#
#                      time3  webpage4               time4  webpage5  \
# 0                      NaT       NaN                 NaT       NaN
# 14     2019-02-04 05:54:56     451.0 2019-02-04 05:54:58     438.0
# 15                     NaT       NaN                 NaT       NaN
# 32                     NaT       NaN                 NaT       NaN
# 34     2018-03-12 07:23:36     867.0 2018-03-12 07:28:57     880.0
# ...                    ...       ...                 ...       ...
# 159930                 NaT       NaN                 NaT       NaN
# 159943 2018-10-12 06:09:53     451.0 2018-10-12 06:09:54     425.0
# 159946                 NaT       NaN                 NaT       NaN
# 159953 2019-02-04 09:58:58       NaN                 NaT       NaN
# 159967 2018-09-12 10:00:10   72458.0 2018-09-12 10:01:29   72458.0
#
#                      time5  ...               time6 webpage7  \
# 0                      NaT  ...                 NaT      NaN
# 14     2019-02-04 05:55:56  ... 2019-02-04 05:55:56    425.0
# 15                     NaT  ...                 NaT      NaN
# 32                     NaT  ...                 NaT      NaN
# 34     2018-03-12 07:28:57  ... 2018-03-12 07:28:58      NaN
# ...                    ...  ...                 ...      ...
# 159930                 NaT  ...                 NaT      NaN
# 159943 2018-10-12 06:10:08  ... 2018-10-12 06:10:08    425.0
# 159946                 NaT  ...                 NaT      NaN
# 159953                 NaT  ...                 NaT      NaN
# 159967 2018-09-12 10:01:30  ...                 NaT      NaN
#
#                      time7 webpage8               time8 webpage9  \
# 0                      NaT      NaN                 NaT      NaN
# 14     2019-02-04 05:55:57    451.0 2019-02-04 05:55:57    971.0
# 15                     NaT      NaN                 NaT      NaN
# 32                     NaT      NaN                 NaT      NaN
# 34                     NaT      NaN                 NaT      NaN
# ...                    ...      ...                 ...      ...
# 159930                 NaT      NaN                 NaT      NaN
# 159943 2018-10-12 06:10:09    438.0 2018-10-12 06:10:09    971.0
# 159946                 NaT      NaN                 NaT      NaN
# 159953                 NaT      NaN                 NaT      NaN
# 159967                 NaT      NaN                 NaT      NaN
#
#                      time9 webpage10  time10 target
# 0                      NaT       NaN     NaT      0
# 14     2019-02-04 05:57:48       NaN     NaT      0
# 15                     NaT       NaN     NaT      0
# 32                     NaT       NaN     NaT      0
# 34                     NaT       NaN     NaT      0
# ...                    ...       ...     ...    ...
# 159930                 NaT       NaN     NaT      0
# 159943 2018-10-12 06:12:25       NaN     NaT      0
# 159946                 NaT       NaN     NaT      0
# 159953                 NaT       NaN     NaT      0
# 159967                 NaT       NaN     NaT      0
#
# [14113 rows x 21 columns]

# %%
df.drop(index=df[df.isna().any(axis=1)].index, inplace=True)

# %%
df.head()
# Out:
#    webpage1               time1  webpage2               time2  webpage3  \
# 1     11722 2019-02-22 07:14:50   12385.0 2019-02-22 07:14:50   50163.0
# 2    192149 2018-12-16 12:35:17     659.0 2018-12-16 12:35:18  192136.0
# 3     10591 2019-02-13 12:40:35     451.0 2019-02-13 12:40:35   77580.0
# 4       438 2018-04-12 06:22:26     425.0 2018-04-12 06:22:26     529.0
# 5     48252 2019-02-20 12:04:13    3129.0 2019-02-20 12:05:08    7562.0
#
#                 time3  webpage4               time4  webpage5  \
# 1 2019-02-22 07:14:51   12385.0 2019-02-22 07:14:51   12398.0
# 2 2018-12-16 12:35:19  192149.0 2018-12-16 12:35:19     633.0
# 3 2019-02-13 12:40:35  227821.0 2019-02-13 12:40:35     633.0
# 4 2018-04-12 06:22:28   65685.0 2018-04-12 06:22:29  187638.0
# 5 2019-02-20 12:05:08     425.0 2019-02-20 12:05:08    3129.0
#
#                 time5  ...               time6  webpage7               time7  \
# 1 2019-02-22 07:14:51  ... 2019-02-22 07:14:51   50163.0 2019-02-22 07:14:52
# 2 2018-12-16 12:35:19  ... 2018-12-16 12:35:19  192136.0 2018-12-16 12:35:20
# 3 2019-02-13 12:41:05  ... 2019-02-13 12:42:14   10591.0 2019-02-13 12:42:14
# 4 2018-04-12 06:22:29  ... 2018-04-12 06:22:29     425.0 2018-04-12 06:22:29
# 5 2019-02-20 12:05:24  ... 2019-02-20 12:05:24     425.0 2019-02-20 12:05:29
#
#    webpage8               time8  webpage9               time9 webpage10  \
# 1   50150.0 2019-02-22 07:14:52   19860.0 2019-02-22 07:15:15   19886.0
# 2  192136.0 2018-12-16 12:35:21  192136.0 2018-12-16 12:35:22  192136.0
# 3  227834.0 2019-02-13 12:42:15  227834.0 2019-02-13 12:42:16  227834.0
# 4   65685.0 2018-04-12 06:22:31  187625.0 2018-04-12 06:22:31  187625.0
# 5     425.0 2019-02-20 12:05:39   30520.0 2019-02-20 12:05:40   26724.0
#
#                time10 target
# 1 2019-02-22 07:15:16      0
# 2 2018-12-16 12:35:24      0
# 3 2019-02-13 12:42:17      0
# 4 2018-04-12 06:22:32      0
# 5 2019-02-20 12:05:40      0
#
# [5 rows x 21 columns]

# %% [markdown]
# * Lets get from data columns some info and then we will delete them all as all data time columns are the same.

# %%
dates = [f'time{i+1}' for i in range(10)]

# %%
from datetime import datetime

# %%
df["time_on_website"] = (df[dates[9]] - df[dates[0]]).apply(lambda x: x.seconds)

# %%
sns.violinplot(x="target", y="time_on_website" ,data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='time_on_website'>

# %%
ides = df[df.time_on_website > 500].index
def temp(x):
    if x in ides:
        return "more"
    else:
        return "less"

# %%
df["more_less"] = df["time_on_website"].apply(lambda x: temp(x))

# %%
df[df.target == 1].more_less.value_counts()[1] / df[df.target == 1].more_less.value_counts()[0] * 100
# Out:
# 2.5165562913907285

# %%
df[df.target == 0].more_less.value_counts()[1] / df[df.target == 0].more_less.value_counts()[0] * 100
# Out:
# 3.399898253835185

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axs = plt.subplots(ncols=2, nrows=1, figsize=(15,5))

sns.violinplot(x="more_less", y="time_on_website" , data=df, ax=axs[0]).set_title('depending on more_less feature')
sns.violinplot(x="target", y="time_on_website" , data=df, ax=axs[1]).set_title('depending on target')
axs[0].set_ylim([-100, 500])
axs[1].set_ylim([-100, 500])
# Out:
# (-100.0, 500.0)

# %% [markdown]
# As we see, time which was spent on the website is not the main feature. We can delete these data, witch time_spending feature has more them 500 value.

# %%
df[df.time_on_website < 0]
# Out:
# Empty DataFrame
# Columns: [webpage1, time1, webpage2, time2, webpage3, time3, webpage4, time4, webpage5, time5, webpage6, time6, webpage7, time7, webpage8, time8, webpage9, time9, webpage10, time10, target, time_on_website, more_less]
# Index: []
#
# [0 rows x 23 columns]

# %%
df["main_date"] = df[dates[0]]

# %%
df.drop(columns=dates, inplace=True)

# %%
temp = []
for key, val in enumerate(df.webpage1.value_counts()):
    if val < 10: 
        temp.append(key)

# %%
df[temp1].target.value_counts()
# Out:
# 0    39436
# 1      211
# Name: target, dtype: int64

# %%
temp1 = []
for i in df.webpage1:
    if i in temp:
        temp1.append(True)
    else:
        temp1.append(False)

# %%
temp1
# Out:
# [False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  ...]

# %%
def to_hour_gaps(i):
    if i in range(0, 6):
        return "night"
    elif i in range(6,12):
        return "morning"
    elif i in range(12, 18):
        return "afternoon"
    else:
        return "evening"

# %%
df["Time"] = df["main_date"].dt.hour.map(to_hour_gaps)

# %%
df["Month"] = df['main_date'].dt.month_name()

# %%
df["Year"] = df['main_date'].apply(lambda x: int(x.year))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\course\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'main_date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-348-1e4b674d4b09> in <module>
# ----> 1 df["year"] = df['main_date'].apply(lambda x: x.year)
#
# ~\anaconda3\envs\course\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\envs\course\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'main_date'

# %%
df.drop(columns="main_date", inplace=True)

# %% [markdown]
# ## Building pipeline

# %% [markdown]
# ### Test pipeline

# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier

import datetime as dt

# %%
test = pd.read_csv("epamdscourseclassification3/test.csv")

# %%
test
# Out:
#        session_id  webpage1                time1  webpage2  \
# 0               0     10318  2019-03-28 06:47:12   10318.0
# 1               1       438  2019-02-28 06:48:05    2453.0
# 2               2      7562  2019-03-18 11:13:31     425.0
# 3               3      8836  2019-03-17 12:18:08   12372.0
# 4               4       451  2019-03-31 09:46:43    9863.0
# ...           ...       ...                  ...       ...
# 93333       93333       659  2019-02-27 10:48:54  111380.0
# 93334       93334      1153  2019-03-24 07:44:51    1127.0
# 93335       93335     13659  2019-03-26 10:06:42   10708.0
# 93336       93336    309513  2019-04-15 09:06:32   15375.0
# 93337       93337    454398  2019-04-25 05:51:52   18729.0
#
#                      time2  webpage3                time3  webpage4  \
# 0      2019-03-28 06:47:42   10318.0  2019-03-28 06:48:12   10318.0
# 1      2019-02-28 06:50:22    2427.0  2019-02-28 06:50:22    2466.0
# 2      2019-03-18 11:13:39    7562.0  2019-03-18 11:18:02     425.0
# 3      2019-03-17 12:18:35   12398.0  2019-03-17 12:18:35   12385.0
# 4      2019-03-31 09:46:44     451.0  2019-03-31 09:46:46    9889.0
# ...                    ...       ...                  ...       ...
# 93333  2019-02-27 10:48:54   13659.0  2019-02-27 10:48:57   10708.0
# 93334  2019-03-24 07:44:51    1153.0  2019-03-24 07:44:53    1127.0
# 93335  2019-03-26 10:16:17   13659.0  2019-03-26 10:18:57   10214.0
# 93336  2019-04-15 09:06:34     191.0  2019-04-15 09:06:35     191.0
# 93337  2019-04-25 05:51:53  454398.0  2019-04-25 05:51:53     529.0
#
#                      time4  webpage5  ...  webpage6                time6  \
# 0      2019-03-28 06:48:42   10318.0  ...   10318.0  2019-03-28 06:49:42
# 1      2019-02-28 06:50:23    2453.0  ...    2466.0  2019-02-28 06:50:59
# 2      2019-03-18 11:18:43     425.0  ...       NaN                  NaN
# 3      2019-03-17 12:18:35   12385.0  ...   12398.0  2019-03-17 12:18:36
# 4      2019-03-31 09:46:46     451.0  ...     425.0  2019-03-31 09:47:46
# ...                    ...       ...  ...       ...                  ...
# 93333  2019-02-27 10:48:57    7562.0  ...   13659.0  2019-02-27 10:48:58
# 93334  2019-03-24 07:44:56     867.0  ...     880.0  2019-03-24 07:45:02
# 93335  2019-03-26 10:20:17   13659.0  ...   10214.0  2019-03-26 10:30:40
# 93336  2019-04-15 09:06:37     256.0  ...     256.0  2019-04-15 09:06:50
# 93337  2019-04-25 05:51:54     542.0  ...  454398.0  2019-04-25 05:51:54
#
#       webpage7                time7  webpage8                time8  webpage9  \
# 0      10318.0  2019-03-28 06:50:12   10318.0  2019-03-28 06:50:42   10318.0
# 1       2427.0  2019-02-28 06:50:59    2453.0  2019-02-28 06:50:59    2453.0
# 2          NaN                  NaN       NaN                  NaN       NaN
# 3      12372.0  2019-03-17 12:18:36     451.0  2019-03-17 12:18:52     425.0
# 4       9928.0  2019-03-31 09:49:43     867.0  2019-03-31 10:05:12     880.0
# ...        ...                  ...       ...                  ...       ...
# 93333  10214.0  2019-02-27 10:48:58   10708.0  2019-02-27 10:48:58    2323.0
# 93334    867.0  2019-03-24 07:45:03    1140.0  2019-03-24 07:45:05    1127.0
# 93335  13659.0  2019-03-26 10:30:42   10214.0  2019-03-26 10:34:41   13659.0
# 93336    191.0  2019-04-15 09:06:52  334538.0  2019-04-15 09:06:54  334551.0
# 93337  75279.0  2019-04-25 05:51:54     542.0  2019-04-25 05:51:55     607.0
#
#                      time9 webpage10               time10
# 0      2019-03-28 06:51:12   10318.0  2019-03-28 06:51:42
# 1      2019-02-28 06:52:06    2466.0  2019-02-28 06:52:11
# 2                      NaN       NaN                  NaN
# 3      2019-03-17 12:18:52     438.0  2019-03-17 12:18:53
# 4      2019-03-31 10:05:12     867.0  2019-03-31 10:05:13
# ...                    ...       ...                  ...
# 93333  2019-02-27 10:50:41    2323.0  2019-02-27 10:50:42
# 93334  2019-03-24 07:45:05    1192.0  2019-03-24 07:45:05
# 93335  2019-03-26 10:34:42       NaN                  NaN
# 93336  2019-04-15 09:06:55     204.0  2019-04-15 09:06:58
# 93337  2019-04-25 05:51:55     581.0  2019-04-25 05:51:55
#
# [93338 rows x 21 columns]

# %%
scaler_pipeline = Pipeline([
    ('impute', SimpleImputer(missing_values=np.nan, strategy='median')),
    ('scale', StandardScaler())
])

# %%
ohe_pipeline = Pipeline([
    ('impute', SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore', ))
])

# %%
ohe = ['time_on_website', 'more_less', 'Time', 'Month', 'year']
# Out:
# ['time_on_website', 'more_less', 'Time', 'Month', 'year']

# %%
['time_on_website', 'more_less', 'Time', 'Month', 'year']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-513-17250328116c> in <module>
# ----> 1 chain(ohe)
#
# NameError: name 'chain' is not defined

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('scaler', scaler_pipeline, ["time_on_website"]),
        ('ohe', ohe_pipeline, ohe)
    ]
)

# %%
LogisticRegression_pipeline = Pipeline([
        ('preprocessing', preprocessor),
        ('classify', LogisticRegression(n_jobs=-1))
    ]
)

# %%
RandomForestClassifier_pipeline = Pipeline([
        ('preprocessing', preprocessor),
        ('classify', RandomForestClassifier(n_estimators=135))
    ]
)

# %%
X = df.drop(columns="target")
y = df.target

# %%
clf = LogisticRegression_pipeline.fit(X, y)
# Out:
# C:\Users\Oleg-Nai\anaconda3\envs\course\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(clf.predict(X), y)
# Out:
# 0.9893867924528302

# %%
LogisticRegression_pipeline
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('scaler',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['time_on_website']),
#                                                  ('ohe',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['time_on_website',
#                                                    'more_less', 'Time', 'Month',
#                                                    'year'])])),
#                 ('classify', LogisticRegression(n_jobs=-1))])

# %%
LogisticRegression_pipeline.named_steps["classify"]
# Out:
# LogisticRegression(n_jobs=-1)

# %%
kfold = KFold(n_splits=5)

# %%
cross_val_score(LogisticRegression_pipeline, X, y, cv=kfold, n_jobs=-1)
# Out:
# array([0.9891677 , 0.9888588 , 0.98930445, 0.99091564, 0.9886874 ])

# %%
cross_val_score(RandomForestClassifier_pipeline, X, y, cv=kfold, n_jobs=-1)
# Out:
# array([0.9891677 , 0.98930445, 0.98964725, 0.99046999, 0.9886874 ])

# %% [markdown]
# ### Real pipeline

# %%
dates = [f'time{i}' for i in range(1,11)]
dates
# Out:
# ['time1',
#  'time2',
#  'time3',
#  'time4',
#  'time5',
#  'time6',
#  'time7',
#  'time8',
#  'time9',
#  'time10']

# %%
test_data = pd.read_csv("epamdscourseclassification3/test.csv", parse_dates=dates, na_values=np.nan)

# %%
test_data.head()
# Out:
#    session_id  webpage1               time1  webpage2               time2  \
# 0           0     10318 2019-03-28 06:47:12   10318.0 2019-03-28 06:47:42
# 1           1       438 2019-02-28 06:48:05    2453.0 2019-02-28 06:50:22
# 2           2      7562 2019-03-18 11:13:31     425.0 2019-03-18 11:13:39
# 3           3      8836 2019-03-17 12:18:08   12372.0 2019-03-17 12:18:35
# 4           4       451 2019-03-31 09:46:43    9863.0 2019-03-31 09:46:44
#
#    webpage3               time3  webpage4               time4  webpage5  ...  \
# 0   10318.0 2019-03-28 06:48:12   10318.0 2019-03-28 06:48:42   10318.0  ...
# 1    2427.0 2019-02-28 06:50:22    2466.0 2019-02-28 06:50:23    2453.0  ...
# 2    7562.0 2019-03-18 11:18:02     425.0 2019-03-18 11:18:43     425.0  ...
# 3   12398.0 2019-03-17 12:18:35   12385.0 2019-03-17 12:18:35   12385.0  ...
# 4     451.0 2019-03-31 09:46:46    9889.0 2019-03-31 09:46:46     451.0  ...
#
#   webpage6               time6 webpage7               time7 webpage8  \
# 0  10318.0 2019-03-28 06:49:42  10318.0 2019-03-28 06:50:12  10318.0
# 1   2466.0 2019-02-28 06:50:59   2427.0 2019-02-28 06:50:59   2453.0
# 2      NaN                 NaT      NaN                 NaT      NaN
# 3  12398.0 2019-03-17 12:18:36  12372.0 2019-03-17 12:18:36    451.0
# 4    425.0 2019-03-31 09:47:46   9928.0 2019-03-31 09:49:43    867.0
#
#                 time8 webpage9               time9 webpage10  \
# 0 2019-03-28 06:50:42  10318.0 2019-03-28 06:51:12   10318.0
# 1 2019-02-28 06:50:59   2453.0 2019-02-28 06:52:06    2466.0
# 2                 NaT      NaN                 NaT       NaN
# 3 2019-03-17 12:18:52    425.0 2019-03-17 12:18:52     438.0
# 4 2019-03-31 10:05:12    880.0 2019-03-31 10:05:12     867.0
#
#                time10
# 0 2019-03-28 06:51:42
# 1 2019-02-28 06:52:11
# 2                 NaT
# 3 2019-03-17 12:18:53
# 4 2019-03-31 10:05:13
#
# [5 rows x 21 columns]

# %%
# class FeautureSelector(BaseEstimator, TransformerMixin):
#     def __init__(self, feature_names):
#         self.feature_names = feature_names

#     def fit(self, X, y=None):
#         return self

#     def transform(self, X, y=None):
#         return X[self.feature_names]


class Transformator_ohe(BaseEstimator, TransformerMixin):
    def __init__(self):
        BaseEstimator.__init__(self)
        TransformerMixin.__init__(self)

    def fit(self, X, y=None):
        return self

    def to_hour_gaps(i):
        if i in range(0, 6):
            return "night"
        elif i in range(6,12):
            return "morning"
        elif i in range(12, 18):
            return "afternoon"
        else:
            return "evening"

    def transform(self, X, y=None):
        """
        This func should return clear X. (year, month, time)
        """
        
        data = X.copy()
        
        main_date = X.time1
        data["Time"] = main_date.dt.hour.map(to_hour_gaps)
        data["Month"] = main_date.dt.month_name()
        data["Year"] = main_date.apply(lambda x: x.year)
        data.drop(columns=X.columns, inplace=True)
        
        return data
    

class Transformator_ss(BaseEstimator, TransformerMixin):
    def __init__(self):
        BaseEstimator.__init__(self)
        TransformerMixin.__init__(self)

    def fit(self, X, y=None):
        return self
    
    def is_date(x):
        return isinstance(x, pd._libs.tslibs.nattype.NaTType)
    
    def transform(self, X, y=None):
        """
        This func should return (time_on_website)
        """
        
        data = X.copy()
        
#         for key, value in enumerate(data.time10):
#             if is_date(i):
#                 data.time10[key] = data.time1[key]
                
        data["time10"] = data["time10"].fillna(value = data["time1"])
        data["Time_on_website"] = (data.time10 - data.time1).apply(lambda x: x.seconds)
        data.drop(columns=X.columns, inplace=True)
        
        return data

# %%
preprocessor_date_ohe = Pipeline([
    ("transformator", Transformator_ohe()),
    ("ohe", OneHotEncoder())
])

preprocessor_date_ss = Pipeline([
    ("transformator", Transformator_ss()),
    ("ohe", RobustScaler(quantile_range=(0.0,75.0)))
])


preprocessor = ColumnTransformer(
    transformers=[
        ('date_ohe', preprocessor_date_ohe, ["time1"]),
        ('date_ss', preprocessor_date_ss, ["time1", "time10"])
    ]
)

# %%
logistic_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("clf", LogisticRegression(n_jobs=-1))
])

# %%
train_data = pd.read_csv("epamdscourseclassification3/train.csv", parse_dates=dates)
train_data.drop(index=train_data[train_data.isna().any(axis=1)].index, inplace=True)

# %%
X_train = train_data.drop(columns="target")
y_train = train_data.target

# %%
logistic_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('date_ohe',
#                                                   Pipeline(steps=[('transformator',
#                                                                    Transformator_ohe()),
#                                                                   ('ohe',
#                                                                    OneHotEncoder())]),
#                                                   ['time1']),
#                                                  ('date_ss',
#                                                   Pipeline(steps=[('transformator',
#                                                                    Transformator_ss()),
#                                                                   ('ohe',
#                                                                    RobustScaler(quantile_range=(0.0,
#                                                                                                 75.0)))]),
#                                                   ['time1', 'time10'])])),
#                 ('clf', LogisticRegression(n_jobs=-1))])

# %%
test_1 = pd.read_csv("epamdscourseclassification3/train.csv", parse_dates=dates)
X = test_1.drop(columns="target")
y = test_1.target

# %%
cross_val_score(logistic_pipeline, X, y, cv=kfold, n_jobs=-1, scoring="roc_auc")
# Out:
# array([0.85571327, 0.87117535, 0.85330812, 0.8615275 , 0.8560854 ])

# %%
model = logistic_pipeline.fit(X_train, y_train)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93338 entries, 0 to 93337
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   session_id  93338 non-null  int64
#  1   webpage1    93338 non-null  int64
#  2   time1       93338 non-null  datetime64[ns]
#  3   webpage2    91859 non-null  float64
#  4   time2       91859 non-null  datetime64[ns]
#  5   webpage3    90606 non-null  float64
#  6   time3       90606 non-null  datetime64[ns]
#  7   webpage4    89674 non-null  float64
#  8   time4       89674 non-null  datetime64[ns]
#  9   webpage5    88744 non-null  float64
#  10  time5       88744 non-null  datetime64[ns]
#  11  webpage6    87929 non-null  float64
#  12  time6       87929 non-null  datetime64[ns]
#  13  webpage7    87143 non-null  float64
#  14  time7       87143 non-null  datetime64[ns]
#  15  webpage8    86409 non-null  float64
#  16  time8       86409 non-null  datetime64[ns]
#  17  webpage9    85685 non-null  float64
#  18  time9       85685 non-null  datetime64[ns]
#  19  webpage10   84959 non-null  float64
#  20  time10      84959 non-null  datetime64[ns]
# dtypes: datetime64[ns](10), float64(9), int64(2)
# memory usage: 15.0 MB

# %%
y_pred = model.predict(test_data)

# %%
# def save_submission(pred):
#     a = pd.Series(pred, name='target', index=pd.Index(range(len(pred)), name='session_id')).to_csv('notebook_submission.csv')

# %%
# submission = pd.DataFrame()
# submission['Id'] = (range(len(y_pred)))
# submission['target'] = y_pred.reshape((y_pred.shape[0]))
# submission.to_csv('sub.csv', index=False)

# %%
np.savetxt("sub.csv", y_pred, delimiter="\n")
